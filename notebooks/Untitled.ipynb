# %%
M = Matrix(GF(2), [[1,0,0,1], [0,0,1,1]])

# %%
M.list()
# Out:
# [1, 0, 0, 1, 0, 0, 1, 1]

# %%
matrix_list = [list(row) for row in M.rows()]

# %%
print(matrix_list)
# Out:
# [[1, 0, 0, 1], [0, 0, 1, 1]]
